# %%
import pandas as pd

# %%
train=pd.read_csv('wm/train_finger.csv')
train
# Out:
#             name        ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  \
# 0        train.0  24.916749  21.330173      3      3        NaN       NaN
# 1        train.1  16.944803  13.660186      0      1  27.577593  2.628402
# 2        train.2  23.434942  18.951645      0      0  36.526304  2.543268
# 3        train.3  21.136972  16.996168      0      1  35.775182  2.598451
# 4        train.4  16.280035  14.176323      0      1  27.584895  2.443323
# ...          ...        ...        ...    ...    ...        ...       ...
# 1060  train.1061  33.310425  24.004339      1      3  53.357565  2.636274
# 1061  train.1062  12.118275  10.624530      0      0  20.388826  2.390361
# 1062  train.1063  21.517512  17.462176      2      1  35.745023  2.447673
# 1063  train.1064  14.527174  12.678904      0      1  23.527792  2.430456
# 1064  train.1065   9.996804   9.615574      0      0  17.119207  2.367530
#
#       SpDiam_A     SpAD_A   SpMAD_A  ...      SRW10     TSRW10          MW  \
# ...

# %%
t_train=pd.read_csv('t_2_train.csv')
t_train
# Out:
#                                                  SMILES  terminal  t1/2 (h)  \
# 0     [Gd+3].COCCNC(=O)CN(CCN(CCN(CC([O-])=O)CC(=O)N...                1.46
# 1       COc1ccc2CN(C)CC[C@@]34C=C[C@H](O)C[C@@H]3Oc1c24                5.30
# 2     C[C@H](\C=C\[C@H](C)C(C)(C)O)[C@H]1CC[C@H]2\C(...                5.30
# 3      c1(n(c2c(C(=O)c3ccccc3C2=O)[n+]1Cc1cnccn1)CCOC)C               24.80
# 4               COC(=O)[C@H](c1ccccc1Cl)N2CCc3c(ccs3)C2                5.06
# ...                                                 ...                 ...
# 1061  CC(C)[C@@H](CC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C...                9.50
# 1062                     CC1=C(C=C(C#N)C(=O)N1)c2ccncc2                0.80
# 1063  c1ccc(cc1)CC[C@H](N[C@@H]1C(N2[C@@H](CCC[N@@]2...               50.60
# 1064               c1cc(ccc1O)[C@@H](CN(C)C)C1(CCCCC1)O                8.40
# 1065                            ClCCN(CCCl)P1(=O)NCCCO1                8.00
#
#       label
# 0         0
# 1         1
# 2         1
# ...

# %%
train_data0=pd.concat([train,t_train],axis=1)
train_data0
# Out:
#                                                    name        ABC      ABCGG  \
# 0     [Gd+3].COCCNC(=O)CN(CCN(CCN(CC([O-])=O)CC(=O)N...  24.916749  21.330173
# 1       COc1ccc2CN(C)CC[C@@]34C=C[C@H](O)C[C@@H]3Oc1c24  16.944803  13.660186
# 2     C[C@H](\C=C\[C@H](C)C(C)(C)O)[C@H]1CC[C@H]2\C(...  23.434942  18.951645
# 3      c1(n(c2c(C(=O)c3ccccc3C2=O)[n+]1Cc1cnccn1)CCOC)C  21.136972  16.996168
# 4               COC(=O)[C@H](c1ccccc1Cl)N2CCc3c(ccs3)C2  16.280035  14.176323
# ...                                                 ...        ...        ...
# 1061  CC(C)[C@@H](CC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C...  33.310425  24.004339
# 1062                     CC1=C(C=C(C#N)C(=O)N1)c2ccncc2  12.118275  10.624530
# 1063  c1ccc(cc1)CC[C@H](N[C@@H]1C(N2[C@@H](CCC[N@@]2...  21.517512  17.462176
# 1064               c1cc(ccc1O)[C@@H](CN(C)C)C1(CCCCC1)O  14.527174  12.678904
# 1065                            ClCCN(CCCl)P1(=O)NCCCO1   9.996804   9.615574
#
# ...

# %%
# for i in range(1066):
#         if train_data0['name'][i]==train_data0['SMILES'][i]:
#             continue
#         else:
#             print(train_data0['name'][i],train_data0['SMILES'][i])

# %%
aa=list(train)
file1=open('wm/finger_name.txt','a')
print(aa,file=file1)
file1.close()

# %%
len(aa)
# Out:
# 1827

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6f6f565106ae> in <module>
# ----> 1 file1.close()
#
# NameError: name 'file1' is not defined
