# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score as ACC
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import roc_auc_score as AUC
from sklearn.metrics import f1_score as F1
def auc_roc(y_test1,pre):
    pre=[p for p in pre[:,1]]
    #print(pre)
    fpr,tpr,threshold = roc_curve(y_test1,pre)###计算真正率和假正率
    roc_auc = auc(fpr,tpr)
    #print('roc_auc:%2f'%(roc_auc))
    return roc_auc
def analyze(pre,real):
    AUC_test=auc_roc(real,pre)
    pre=np.argmax(pre,axis=1)
    #print(pre)
    m=confusion_matrix(pre,real, labels=[0,1], sample_weight=None)
    print(m)
    tp, fp, fn, tn = m.ravel()
    TPR=tp/(tp+fn)
    TNR=tn/(tn+fp)
    ACC_test=ACC(real,pre)
    #AUC_test=auc_roc(real,pre)
    MCC_test=MCC(real,pre)
    F1_test=F1(real,pre)
    print('敏感度TPR：%2f，特异度TNR：%2f，ACC：%2f，AUC：%2f,MCC：%2f,F1：%2f'%(TPR,TNR,ACC_test,AUC_test,MCC_test,F1_test))
    return ACC_test

# %%
def count(a,b,c):
    n_0=0
    if a==0:
        n_0+=1
    if b==0:
        n_0+=1
    if c==0:
        n_0+=1
    if n_0>=2:
        return 0
    else:
        return 1 
def analyze111(pre,real):
    m=confusion_matrix( pre,real, labels=[0,1], sample_weight=None)
    print(m)
    tp, fp, fn, tn = m.ravel()
    print(tp, fp, fn, tn)
    TPR=tp/(tp+fn)
    TNR=tn/(tn+fp)
    ACC_test=ACC(real,pre)
    AUC_test=AUC(real,pre)
    MCC_test=MCC(real,pre)
    print('敏感度TPR：%2f，特异度TNR：%2f，ACC：%2f，AUC：%2f，MCC：%2f'%(TPR,TNR,ACC_test,AUC_test,MCC_test))

# %%
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('data_all.csv')
data
# Out:
#            DPSA1     FNSA3     FPSA1           MW  nCl     FPSA3  nH  \
# 0     287.629288 -0.109059  0.601570  1414.518432    0  0.061149  84
# 1     129.543006 -0.031597  0.608418   352.134241    1  0.028462  21
# 2     220.572237 -0.043353  0.667194   407.233955    1  0.031405  34
# 3      68.884136 -0.082446  0.566120   320.094311    0  0.044068  16
# 4      55.669458 -0.090027  0.555633   285.103479    0  0.032846  19
# ...          ...       ...       ...          ...  ...       ...  ..
# 1326  458.670902 -0.045692  0.744919   627.464493    0  0.038213  65
# 1327   65.197994 -0.079354  0.579472   211.074562    0  0.042656   9
# 1328  110.340618 -0.093054  0.588110   389.195071    0  0.045955  27
# 1329  203.749504 -0.058050  0.708824   263.188529    0  0.041742  25
# 1330   43.324992 -0.073126  0.552598   260.024820    2  0.024895  15
#
#             MOMI-X        MOMI-Y        MOMI-Z  FilterItLogS    SLogP  label
# 0     74808.086673  63632.345988  22018.177370     -2.673257 -7.70358      1
# 1      5282.827378   4132.785706   1704.037293     -6.329876  5.42570      1
# 2      5792.165230   4784.090259   2622.331064     -4.800029  3.58610      1
# 3      4187.577280   3308.329532   1089.951595     -2.804857  0.81249      0
# 4      3307.032656   3160.454612    785.256861     -2.816359  2.19550      1
# ...            ...           ...           ...           ...      ...    ...
# 1326  19037.041030  15186.418266   6381.976037     -6.603546  5.55320      1
# 1327   1916.007065   1611.033972    467.171102     -3.800014  1.61700      0
# 1328   6579.901082   6271.398751   1567.433464     -1.826444  1.11700      1
# 1329   2553.972089   2018.893156   1020.624863     -2.864117  2.73260      1
# 1330   1920.592807   1400.839576    926.865191     -2.710849  1.88400      1
#
# [1331 rows x 13 columns]

# %%
data=data.replace(np.NaN, 0)

x=np.array(data.iloc[:,:-1])

y=np.array(data.iloc[:,-1])

# %%
index=[]
for i in range(100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i,stratify=y)
    #rf0=RandomForestClassifier(n_estimators=30,min_samples_leaf=10, max_depth=12)#n_estimators=20,min_samples_leaf=12, max_depth=12,min_samples_split=7 )#, min_samples_split=5,  
                                    # min_samples_leaf=6,max_features=25 , random_state=10
    #rf0=XGBClassifier(n_estimators=20,max_depth=5,learning_rate=0.2)#,max_depth=5)#n_estimators=210)#,max_depth=7,learning_rate=0.105)
    rf0=GradientBoostingClassifier(n_estimators=35)
    rf0.fit(x_train,y_train)
    #pre_rf_train=rf0.predict_proba(x_train)
    #aa0=analyze(pre_rf_train,y_train)
    print(i)
    pre_rf_test=rf0.predict_proba(x_test)
    aa0=analyze(pre_rf_test,y_test)
    if aa0>0.7:
        index.append(i)
# Out:
# 0
# [[ 35  30]
#  [ 73 129]]
# 敏感度TPR：0.324074，特异度TNR：0.811321，ACC：0.614232，AUC：0.604065,MCC：0.154839,F1：0.714681
# 1
# [[ 43  26]
#  [ 65 133]]
# 敏感度TPR：0.398148，特异度TNR：0.836478，ACC：0.659176，AUC：0.690601,MCC：0.263045,F1：0.745098
# 2
# [[ 48  27]
#  [ 60 132]]
# 敏感度TPR：0.444444，特异度TNR：0.830189，ACC：0.674157，AUC：0.695172,MCC：0.299904,F1：0.752137
# 3
# [[ 39  34]
#  [ 69 125]]
# 敏感度TPR：0.361111，特异度TNR：0.786164，ACC：0.614232，AUC：0.609917,MCC：0.162172,F1：0.708215
# 4
# [[ 39  37]
#  [ 69 122]]
# 敏感度TPR：0.361111，特异度TNR：0.767296，ACC：0.602996，AUC：0.660581,MCC：0.139661,F1：0.697143
# 5
# [[ 35  19]
#  [ 73 140]]
# 敏感度TPR：0.324074，特异度TNR：0.880503，ACC：0.655431，AUC：0.665240,MCC：0.249966,F1：0.752688
# 6
# [[ 52  38]
#  [ 56 121]]
# 敏感度TPR：0.481481，特异度TNR：0.761006，ACC：0.647940，AUC：0.644334,MCC：0.251763,F1：0.720238
# 7
# [[ 49  27]
#  [ 59 132]]
# 敏感度TPR：0.453704，特异度TNR：0.830189，ACC：0.677903，AUC：0.677411,MCC：0.308774,F1：0.754286
# 8
# [[ 42  25]
#  [ 66 134]]
# 敏感度TPR：0.388889，特异度TNR：0.842767，ACC：0.659176，AUC：0.664337,MCC：0.262242,F1：0.746518
# 9
# [[ 53  23]
#  [ 55 136]]
# 敏感度TPR：0.490741，特异度TNR：0.855346，ACC：0.707865，AUC：0.730695,MCC：0.376419,F1：0.777143
# 敏感度TPR：0.342593，特异度TNR：0.823899，ACC：0.629213，AUC：0.613994,MCC：0.190402,F1：0.725762
# 96
# [[ 50  41]
#  [ 58 118]]
# 敏感度TPR：0.462963，特异度TNR：0.742138，ACC：0.629213，AUC：0.639646,MCC：0.212374,F1：0.704478
# 97
# [[ 45  31]
#  [ 63 128]]
# 敏感度TPR：0.416667，特异度TNR：0.805031，ACC：0.647940，AUC：0.671704,MCC：0.241129,F1：0.731429
# 98
# [[ 37  24]
#  [ 71 135]]
# 敏感度TPR：0.342593，特异度TNR：0.849057，ACC：0.644195，AUC：0.670073,MCC：0.224037,F1：0.739726
# 99
# [[ 47  37]
#  [ 61 122]]
# 敏感度TPR：0.435185，特异度TNR：0.767296，ACC：0.632959，AUC：0.673829,MCC：0.214008,F1：0.713450

# %%
index
# Out:
# [9]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=51,stratify=y)

# %%
num_samples=int(x_train.shape[0]/3)
num_samples
# Out:
# 354

# %%
i=0
rf0=RandomForestClassifier(n_estimators=30,min_samples_leaf=10, max_depth=12,)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
rf0.fit(train_data,train_label)
#pre_rf0_train=rf0.predict_proba(train_data)
#aa0=analyze(pre_rf0_train,train_label)
pre_rf0_val=rf0.predict_proba(val_data)
aa0=analyze(pre_rf0_val,val_label)
pre_rf0_test=rf0.predict_proba(x_test)
analyze(pre_rf0_test,y_test)
pre=(pre_rf0_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 65  44]
#  [ 86 159]]
# 敏感度TPR：0.430464，特异度TNR：0.783251，ACC：0.632768，AUC：0.652856,MCC：0.228968,F1：0.709821
# [[ 52  26]
#  [ 56 133]]
# 敏感度TPR：0.481481，特异度TNR：0.836478，ACC：0.692884，AUC：0.724843,MCC：0.343166,F1：0.764368
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e4998a4e90a1> in <module>
#      13 pre_rf0_test=rf0.predict_proba(x_test)
#      14 analyze(pre_rf0_test,y_test)
# ---> 15 pre=(pre_rf0_test+pre_gbm1_test+pre_xg1_test)/3.0
#      16 analyze(pre,y_test)
#
# NameError: name 'pre_gbm1_test' is not defined

# %%
save_rfmodel('rf0_no',rf0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-82e29df09a9b> in <module>
# ----> 1 save_rfmodel('rf0_no',rf0)
#
# NameError: name 'rf0' is not defined

# %%
i=1
rf1=RandomForestClassifier(n_estimators=30,min_samples_leaf=10, max_depth=12,)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
rf1.fit(train_data,train_label)
#pre_rf1_train=rf1.predict_proba(train_data)
#aa0=analyze(pre_rf1_train,train_label)
pre_rf1_val=rf1.predict_proba(val_data)
aa0=analyze(pre_rf1_val,val_label)
pre_rf1_test=rf1.predict_proba(x_test)
analyze(pre_rf1_test,y_test)
pre=(pre_rf1_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 51  45]
#  [ 89 169]]
# 敏感度TPR：0.364286，特异度TNR：0.789720，ACC：0.621469，AUC：0.677303,MCC：0.169380,F1：0.716102
# [[ 49  26]
#  [ 59 133]]
# 敏感度TPR：0.453704，特异度TNR：0.836478，ACC：0.681648，AUC：0.731336,MCC：0.316883,F1：0.757835
# [[ 49  22]
#  [ 59 137]]
# 敏感度TPR：0.453704，特异度TNR：0.861635，ACC：0.696629，AUC：0.739401,MCC：0.350292,F1：0.771831
# 0.6966292134831461

# %%
i=2
rf2=RandomForestClassifier(n_estimators=30,min_samples_leaf=10, max_depth=12,)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
rf2.fit(train_data,train_label)
#pre_rf2_train=rf2.predict_proba(train_data)
#aa0=analyze(pre_rf2_train,train_label)
pre_rf2_val=rf2.predict_proba(val_data)
aa0=analyze(pre_rf2_val,val_label)
pre_rf2_test=rf2.predict_proba(x_test)
analyze(pre_rf2_test,y_test)
pre=(pre_rf2_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 59  44]
#  [ 81 170]]
# 敏感度TPR：0.421429，特异度TNR：0.794393，ACC：0.646893，AUC：0.639186,MCC：0.232332,F1：0.731183
# [[ 60  36]
#  [ 48 123]]
# 敏感度TPR：0.555556，特异度TNR：0.773585，ACC：0.685393，AUC：0.737829,MCC：0.336634,F1：0.745455
# [[ 53  24]
#  [ 55 135]]
# 敏感度TPR：0.490741，特异度TNR：0.849057，ACC：0.704120，AUC：0.750349,MCC：0.368136,F1：0.773639
# 0.704119850187266

# %%
i=0
xg0=XGBClassifier(n_estimators=20,max_depth=5,learning_rate=0.2)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
xg0.fit(train_data,train_label)
pre_xg0_train=xg0.predict_proba(train_data)
aa0=analyze(pre_xg0_train,train_label)
pre_xg0_val=xg0.predict_proba(val_data)
aa0=analyze(pre_xg0_val,val_label)
pre_xg0_test=xg0.predict_proba(x_test)
analyze(pre_xg0_test,y_test)
# Out:
# [[245   9]
#  [ 35 421]]
# 敏感度TPR：0.875000，特异度TNR：0.979070，ACC：0.938028，AUC：0.987450,MCC：0.870778,F1：0.950339
# [[ 61  52]
#  [ 90 151]]
# 敏感度TPR：0.403974，特异度TNR：0.743842，ACC：0.598870，AUC：0.619271,MCC：0.156823,F1：0.680180
# [[ 54  39]
#  [ 54 120]]
# 敏感度TPR：0.500000，特异度TNR：0.754717，ACC：0.651685，AUC：0.692290,MCC：0.262393,F1：0.720721
# 0.651685393258427

# %%
i=1
xg1=XGBClassifier(n_estimators=20,max_depth=5,learning_rate=0.05)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
xg1.fit(train_data,train_label)
#pre_xg1_train=xg1.predict_proba(train_data)
#aa0=analyze(pre_xg1_train,train_label)
pre_xg1_val=xg1.predict_proba(val_data)
aa0=analyze(pre_xg1_val,val_label)
pre_xg1_test=xg1.predict_proba(x_test)
analyze(pre_xg1_test,y_test)
pre=(pre_rf1_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 50  35]
#  [ 90 179]]
# 敏感度TPR：0.357143，特异度TNR：0.836449，ACC：0.646893，AUC：0.659846,MCC：0.221601,F1：0.741201
# [[ 48  27]
#  [ 60 132]]
# 敏感度TPR：0.444444，特异度TNR：0.830189，ACC：0.674157，AUC：0.714506,MCC：0.299904,F1：0.752137
# [[ 53  23]
#  [ 55 136]]
# 敏感度TPR：0.490741，特异度TNR：0.855346，ACC：0.707865，AUC：0.733229,MCC：0.376419,F1：0.777143
# 0.7078651685393258

# %%
i=2
xg2=XGBClassifier(n_estimators=20,max_depth=5,learning_rate=0.2)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
xg2.fit(train_data,train_label)
pre_xg2_train=xg2.predict_proba(train_data)
aa0=analyze(pre_xg2_train,train_label)
pre_xg2_val=xg2.predict_proba(val_data)
aa0=analyze(pre_xg2_val,val_label)
pre_xg2_test=xg2.predict_proba(x_test)
analyze(pre_xg2_test,y_test)
# Out:
# [[252  12]
#  [ 39 407]]
# 敏感度TPR：0.865979，特异度TNR：0.971360，ACC：0.928169，AUC：0.980079,MCC：0.852091,F1：0.941040
# [[ 47  42]
#  [ 93 172]]
# 敏感度TPR：0.335714，特异度TNR：0.803738，ACC：0.618644，AUC：0.601118,MCC：0.157174,F1：0.718163
# [[ 55  36]
#  [ 53 123]]
# 敏感度TPR：0.509259，特异度TNR：0.773585，ACC：0.666667，AUC：0.721815,MCC：0.292874,F1：0.734328
# 0.6666666666666666

# %%
i=0
gbm0=GradientBoostingClassifier(n_estimators=20)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
gbm0.fit(train_data,train_label)
pre_gbm0_train=gbm0.predict_proba(train_data)
aa0=analyze(pre_gbm0_train,train_label)
pre_gbm0_val=gbm0.predict_proba(val_data)
aa0=analyze(pre_gbm0_val,val_label)
pre_gbm0_test=gbm0.predict_proba(x_test)
analyze(pre_gbm0_test,y_test)
# Out:
# [[140  26]
#  [140 404]]
# 敏感度TPR：0.500000，特异度TNR：0.939535，ACC：0.766197，AUC：0.837616,MCC：0.507520,F1：0.829569
# [[ 54  45]
#  [ 97 158]]
# 敏感度TPR：0.357616，特异度TNR：0.778325，ACC：0.598870，AUC：0.643591,MCC：0.149796,F1：0.689956
# [[ 53  30]
#  [ 55 129]]
# 敏感度TPR：0.490741，特异度TNR：0.811321，ACC：0.681648，AUC：0.691242,MCC：0.320301,F1：0.752187
# 0.6816479400749064

# %%
i=1
gbm1=GradientBoostingClassifier(n_estimators=20)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
gbm1.fit(train_data,train_label)
##pre_gbm1_train=gbm1.predict_proba(train_data)
#aa0=analyze(pre_gbm1_train,train_label)
pre_gbm1_val=gbm1.predict_proba(val_data)
aa0=analyze(pre_gbm1_val,val_label)
pre_gbm1_test=gbm1.predict_proba(x_test)
analyze(pre_gbm1_test,y_test)
pre=(pre_rf1_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 45  34]
#  [ 95 180]]
# 敏感度TPR：0.321429，特异度TNR：0.841121，ACC：0.635593，AUC：0.651669,MCC：0.190888,F1：0.736196
# [[ 46  20]
#  [ 62 139]]
# 敏感度TPR：0.425926，特异度TNR：0.874214，ACC：0.692884，AUC：0.716777,MCC：0.341479,F1：0.772222
# [[ 47  22]
#  [ 61 137]]
# 敏感度TPR：0.435185，特异度TNR：0.861635，ACC：0.689139，AUC：0.732879,MCC：0.332772,F1：0.767507
# 0.6891385767790262

# %%
i=2
gbm2=GradientBoostingClassifier(n_estimators=20)#, min_samples_split=5,  
                                # min_samples_leaf=6,max_features=25 , random_state=10)
val_data= x_train[i*num_samples:(i+1)*num_samples,:]
val_label= y_train[i * num_samples:(i + 1) * num_samples]
train_data=np.concatenate([x_train[:i*num_samples,:],x_train[(i+1)*num_samples:,:]],axis=0)
train_label = np.concatenate([y_train[:i*num_samples], y_train[(i + 1) * num_samples:]], axis=0)
gbm2.fit(train_data,train_label)
pre_gbm2_train=gbm2.predict_proba(train_data)
aa0=analyze(pre_gbm2_train,train_label)
pre_gbm2_val=gbm2.predict_proba(val_data)
aa0=analyze(pre_gbm2_val,val_label)
pre_gbm2_test=gbm2.predict_proba(x_test)
analyze(pre_gbm2_test,y_test)
# Out:
# [[165  52]
#  [126 367]]
# 敏感度TPR：0.567010，特异度TNR：0.875895，ACC：0.749296，AUC：0.819132,MCC：0.472837,F1：0.804825
# [[ 45  41]
#  [ 95 173]]
# 敏感度TPR：0.321429，特异度TNR：0.808411，ACC：0.615819，AUC：0.619226,MCC：0.148034,F1：0.717842
# [[ 52  30]
#  [ 56 129]]
# 敏感度TPR：0.481481，特异度TNR：0.811321，ACC：0.677903，AUC：0.715030,MCC：0.311524,F1：0.750000
# 0.6779026217228464

# %%
pre=(pre_rf1_test+pre_gbm1_test+pre_xg1_test)/3.0
analyze(pre,y_test)
# Out:
# [[ 51  25]
#  [ 57 134]]
# 敏感度TPR：0.472222，特异度TNR：0.842767，ACC：0.692884，AUC：0.726590,MCC：0.342597,F1：0.765714
# 0.6928838951310862

# %%
pre0=np.argmax(pre_rf1_test,axis=1)
pre1=np.argmax(pre_gbm1_test,axis=1)
pre2=np.argmax(pre_xg1_test,axis=1)
r=0
z=0
toupiao_label=[]
for i in range(267):
    if pre0[i]==pre1[i]==pre2[i]:
        r+=1
        toupiao_label.append(pre0[i])
    else:
        #print(pre0[i],pre1[i],pre2[i])
        #print(count(pre0[i],pre1[i],pre2[i]),exp_test[i]) 
        z+=1
        toupiao_label.append(count(pre0[i],pre1[i],pre2[i]))
print(r,z)
#print(toupiao_label)
analyze111(toupiao_label,y_test)
# Out:
# 216 51
# [[ 49  26]
#  [ 59 133]]
# 49 26 59 133
# 敏感度TPR：0.453704，特异度TNR：0.836478，ACC：0.681648，AUC：0.645091，MCC：0.316883

# %%
import pickle
def save_rfmodel(name,model):
    model_name=name+'.pkl'
    with open(model_name, 'ab') as f:
        pickle.dump(model, f)
def rfmodel_pre(model_name,x,y):
    with open(model_name,'rb') as md:
        model=pickle.load(md)
    pre=prediction(model,x,y)
    return pre

# %%
save_rfmodel('rf1',rf2)
save_rfmodel('xg1',xg1)
save_rfmodel('gbm1',gbm1)
